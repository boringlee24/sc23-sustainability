# %%
##part 3 fig -- updated
import matplotlib.pyplot as plt
import matplotlib.pyplot as mp
from matplotlib import rcParams
from matplotlib.ticker import MultipleLocator
import statistics as st
import random
import numpy as np
random.seed(1234)
##plotting styles
plt.style.use(['default'])
mp.rcParams['pdf.fonttype'] = 42
mp.rcParams['ps.fonttype'] = 42
plt.rc('axes', axisbelow=True)

# %%
##plotting styles
plt.style.use(['default'])
explode = (0., 0,0,0,0)
##plotting
barWidth=0.65
fig = mp.figure(figsize=(9,2.7))
mp.subplots_adjust(wspace=0.2, hspace=0.2)

##subplot frontier
ax = mp.subplot(131)
gpu=31402.69029*37632
cpu=16927.54971*9408
dram=7160*75264
ssd=20688.7551*18240
hdd=22111.04358*44480
ax.pie([gpu,cpu,dram,ssd,hdd], colors=["#f0f921", "#f89540", "dodgerblue", "rebeccapurple", "#0d0887"], startangle = 90, explode=explode, wedgeprops={"edgecolor":"k",'linewidth': 1, 'linestyle': 'solid', 'antialiased': True})
###
centre_circle = plt.Circle((0,0),0.70,fc='white', edgecolor='black')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax.axis('equal')  
plt.tight_layout()
###
ax.tick_params(labelsize=15)
ax.text(-0.4,-0.05,"Frontier", fontsize=15,color='black')
ax.text(-1,0.86,"36%", fontsize=15,color='black')
ax.text(-0.9,-1,"5%", fontsize=15,color='black')
ax.text(0.,-1.2,"17%", fontsize=15,color='black')
ax.text(0.7,-0.9,"12%", fontsize=15,color='black')
ax.text(1.05,0,"30%", fontsize=15,color='black')



##subplot frontier
ax = mp.subplot(132)
gpu=31402.69029*10240
cpu=16927.54971*5632
dram=7160*27520
ssd=20688.7551*2240
hdd=22111.04358*5120
ax.pie([gpu,cpu,dram,ssd,hdd], colors=["#f0f921", "#f89540", "dodgerblue", "rebeccapurple", "#0d0887"], startangle = 90, explode=explode, wedgeprops={"edgecolor":"k",'linewidth': 1, 'linestyle': 'solid', 'antialiased': True})
###
centre_circle = plt.Circle((0,0),0.70,fc='white', edgecolor='black')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax.axis('equal')  
plt.tight_layout()
###
ax.tick_params(labelsize=15)
ax.text(-0.25,-0.05,"LUMI", fontsize=15,color='black')
ax.text(-1,0.85,"42%", fontsize=15,color='black')
ax.text(-0.4,-1.2,"12%", fontsize=15,color='black')
ax.text(0.7,-0.9,"25%", fontsize=15,color='black')
ax.text(0.95,0.4,"6%", fontsize=15,color='black')
ax.text(0.25,1.0,"15%", fontsize=15,color='black')


##subplot frontier
ax = mp.subplot(133)
gpu=26356.568*6144 + 28956.568*1024
cpu=16927.54971*7980
dram=7160*32128
ssd=20688.7551*11213
hdd=0
ax.pie([gpu,cpu,dram,ssd,hdd], colors=["#f0f921", "#f89540", "dodgerblue", "rebeccapurple", "#0d0887"], startangle = 90, explode=explode, wedgeprops={"edgecolor":"k",'linewidth': 1, 'linestyle': 'solid', 'antialiased': True})
# ax.pie([gpu,cpu,dram,ssd,hdd], colors=["#f0f921", "#f89540", "dodgerblue", "rebeccapurple", "#0d0887"], startangle = 90, explode=explode, wedgeprops={"edgecolor":"k",'linewidth': 1, 'linestyle': 'solid', 'antialiased': True})
###
centre_circle = plt.Circle((0,0),0.70,fc='white', edgecolor='black')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax.axis('equal')  
plt.tight_layout()
###
ax.tick_params(labelsize=15)
ax.text(-0.33,-0.2,"Perlm-\nutter", fontsize=15,color='black')
ax.text(-1,0.86,"22%", fontsize=15,color='black')
ax.text(-1.48,-0.2,"18%", fontsize=15,color='black')
ax.text(0.7,-0.9,"30%", fontsize=15,color='black')
ax.text(0.95,0.4,"30%", fontsize=15,color='black')

ax = mp.subplot(131)
ax.bar([0], 0 , width = 0, color='#f0f921',edgecolor = 'black',capsize=15, label='GPU', zorder=3)
ax.bar([0], 0 , width = 0, color='#f89540',edgecolor = 'black',capsize=15, label='CPU', zorder=3)
ax.bar([0], 0 , width = 0, color='dodgerblue',edgecolor = 'black',capsize=15, label='DRAM', zorder=3)
ax.bar([0], 0 , width = 0, color='rebeccapurple',edgecolor = 'black',capsize=15, label='SSD', zorder=3)
ax.bar([0], 0 , width = 0, color='#0d0887',edgecolor = 'black',capsize=15, label='HDD', zorder=3)

ax.legend(loc=3,mode='expand',handlelength=1,handletextpad=0.2,  bbox_to_anchor=(0.55,1.05,2.25,0.8),ncol=5,fontsize=15, borderaxespad=0, frameon=False)
plt.savefig("./figures/hpc_carbon.pdf", bbox_inches="tight")
